# %%
# %matplotlib inline

# %%
# Import Dependencies 
import matplotlib.pyplot as plt 
import statistics 
import numpy as np

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis,y_axis)

# %%
# Create the plot with ax.plot()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt() broken up 
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
### OOF Challenge

# %%
# Print out chart
fig, ax = plt.subplots()

# Set x, y, line color, width, marker, and add label
ax.plot(x_axis, y_axis,color = "green", marker = "D", linewidth = "2", label= "Boston")

# Add legend using "Boston" label
ax.legend()

# Add Title and Axes labels
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare ($)")

# Add Grid
ax.grid()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the bar plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the horizontal bar chart plot
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Customize the chart 
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
plt.gca().invert_yaxis()
# Create labels for the x and y axe|s.
plt.xlabel("Fare($)")
plt.ylabel("Date")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
### BAR CHARTS USING OBJECT ORIENTED APPROACH

# %%
# Set x and y 
fig, ax = plt.subplots()

# Set x, y, line color, width, marker, and add label
ax.barh(x_axis, y_axis, color = "magenta", label = "Boston")
plt.gca().invert_yaxis()

# Add legend using "Boston" label
ax.legend()

# Add Title and Axes labels
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fare ($)")
ax.set_ylabel("Date")

# Add Grid
# Out:
# Text(0, 0.5, 'Date')

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Creare scatter plot with .plot method
plt.plot(x_axis, y_axis, "o")

# %%
# Create scatter plot usint .scatter 
plt.scatter(y_axis, x_axis, c='r', s=y_axis)

# Flip y axis to get right order 
plt.gca().invert_yaxis()

# Label the axes and add title
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Creating bubble chart
plt.scatter(x_axis, y_axis)

# %%
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Make y axis larger 
# y_axis_larger = []
# for data in y_axis:
#   y_axis_larger.append(data*3)

# plt.scatter(x_axis, y_axis, s=y_axis_larger)

## OR

plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
# Create Scatter plot using Object Oriented Interface 
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Same scatter plot but with different sized bubbles
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Skill drill 
fig, ax = plt.subplots()

# Plot axes and make size bigger based on y, set colors, line width, edges and alpha
ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], color = "skyblue" , alpha = 0.9, edgecolors="black", linewidths=2, label= "Boston")

# Invert y axis to correct order 
plt.gca().invert_yaxis()

# Add title and x, y labels 
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Fare($")
ax.set_ylabel("Month")

# Set limits 
ax.set_xlim(0 , 50)
# Out:
# (0.0, 50.0)

# %%
# Set size of Chart
plt.subplots(figsize=(8, 8))

# Plot Chart
plt.pie(y_axis, labels=x_axis)

# Show chart
plt.show()

# %%
# Make variable called explode that lets us explode the 7 item, or march 
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

# Make variable for colors
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", 
          "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]

# Set size of Chart
plt.subplots(figsize=(8, 8))

# Plot Chart
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%', shadow = True, colors = colors)

# Show chart
plt.show()

# %%
# Create a Pie Chart Using the Object-Oriented Interface 
fig, ax = plt.subplots()
ax.pie(y_axis,labels=x_axis)
plt.show()

# %%
# Create line chart with error bars 

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Get the standard deviation of the values in the y-axis.
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
# Plot bar chart with error bars
plt.errorbar(x_axis, y_axis, yerr=stdev)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Add caps to bars 
plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# Error Bars on line chart using object orientation method 
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# Add error bars to bar chart 
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
# Eror bars on bar chart using object orientation 
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.show()

# %%
# Changing x ticks using Numpy on hbar chart 

# Plot chart 
plt.barh(x_axis, y_axis)

# Change x ticks 
plt.xticks(np.arange(0, 51, step=5.0))

# Invert y axis 
plt.gca().invert_yaxis()

# %%
# Create the same graph as above with Object Orientation 

# Set up chart 
fig, ax = plt.subplots()

# PLot
ax.barh(x_axis, y_axis)

# Set ticks 
ax.set_xticks(np.arange(0, 51, step=5.0))

# Show
plt.show()

# %%
# Setting minor ticks 
from matplotlib.ticker import MultipleLocator

# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))

ax.barh(x_axis, y_axis)

ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))

plt.show()
